# %%
# %pwd
# Out:
# 'c:\\ex\\MLDL'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#학습셋의 변형을 설정하는 부분입니다. 
train_datagen = ImageDataGenerator(rescale=1./255,          # 주어진 이미지의 크기를 설정합니다.
                                  horizontal_flip=True,     # 수평 대칭 이미지를 50% 확률로 만들어 추가합니다.
                                  width_shift_range=0.1,    # 전체 크기의 15% 범위에서 좌우로 이동합니다.
                                  height_shift_range=0.1,   # 마찬가지로 위, 아래로 이동합니다.
                                  #rotation_range=5,        # 정해진 각도만큼 회전시킵니다.
                                  #shear_range=0.7,         # 좌표 하나를 고정시키고 나머지를 이동시킵니다.
                                  #zoom_range=1.2,          # 확대 또는 축소시킵니다.
                                  #vertical_flip=True,      # 수직 대칭 이미지를 만듭니다.
                                  #fill_mode='nearest'      # 빈 공간을 채우는 방법입니다. nearest 옵션은 가장 비슷한 색으로 채우게 됩니다.
                                  )

# %%
import os
if not os.path.exists("./data/train"):
    os.makedirs("./data/train")

# %%
train_generator = train_datagen.flow_from_directory(
       './data/train',   # 학습셋이 있는 폴더의 위치입니다.
       target_size=(150, 150),
       batch_size=5,
       class_mode='binary')
# Out:
# Found 160 images belonging to 2 classes.

# %%
# 테스트셋은 이미지 부풀리기 과정을 진행하지 않습니다.
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
test_generator = test_datagen.flow_from_directory(
       './data/test',   # 테스트셋이 있는 폴더의 위치입니다.
       target_size=(150, 150),
       batch_size=5,
       class_mode='binary')
# Out:
# Found 120 images belonging to 2 classes.

# %%
# 테스트셋은 이미지 부풀리기 과정을 진행하지 않습니다.
test_datagen = ImageDataGenerator(rescale=1./255)  

test_generator = test_datagen.flow_from_directory(
       './data/test',   # 테스트셋이 있는 폴더의 위치입니다.
       target_size=(150, 150),
       batch_size=5,
       class_mode='binary')
# Out:
# Found 120 images belonging to 2 classes.

# %%
# 앞서 배운 CNN 모델을 만들어 적용해 보겠습니다.
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(150,150,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  activation (Activation)     (None, 148, 148, 32)      0
#
#  max_pooling2d (MaxPooling2  (None, 74, 74, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        9248
#
#  activation_1 (Activation)   (None, 72, 72, 32)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 36, 36, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  activation_2 (Activation)   (None, 34, 34, 64)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 17, 17, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 64)                1183808
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
#  activation_4 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 1212513 (4.63 MB)
# Trainable params: 1212513 (4.63 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# !pip install SciPy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: SciPy in c:\programdata\anaconda3\envs\mldltest1\lib\site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in c:\programdata\anaconda3\envs\mldltest1\lib\site-packages (from SciPy) (1.24.3)

# %%
#모델 실행의 옵션을 설정합니다. 
model.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(learning_rate=0.0002), metrics=['accuracy'])

# 학습의 조기 중단을 설정합니다.
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=5)

#모델을 실행합니다
history = model.fit(
       train_generator,
       epochs=100,
       validation_data=test_generator,
       validation_steps=10, 
       callbacks=[early_stopping_callback])
# Out:
# Epoch 1/100
# 32/32 [==============================] - 4s 88ms/step - loss: 0.7047 - accuracy: 0.4313 - val_loss: 0.6913 - val_accuracy: 0.4800
# Epoch 2/100
# 32/32 [==============================] - 2s 71ms/step - loss: 0.6935 - accuracy: 0.5562 - val_loss: 0.6955 - val_accuracy: 0.4200
# Epoch 3/100
# 32/32 [==============================] - 2s 69ms/step - loss: 0.6889 - accuracy: 0.5375 - val_loss: 0.6615 - val_accuracy: 0.5800
# Epoch 4/100
# 32/32 [==============================] - 2s 66ms/step - loss: 0.6943 - accuracy: 0.4875 - val_loss: 0.6898 - val_accuracy: 0.5800
# Epoch 5/100
# 32/32 [==============================] - 2s 68ms/step - loss: 0.6758 - accuracy: 0.6187 - val_loss: 0.6792 - val_accuracy: 0.5000
# Epoch 6/100
# 32/32 [==============================] - 2s 66ms/step - loss: 0.6587 - accuracy: 0.6500 - val_loss: 0.6555 - val_accuracy: 0.5400
# Epoch 7/100
# 32/32 [==============================] - 2s 65ms/step - loss: 0.6713 - accuracy: 0.5813 - val_loss: 0.6404 - val_accuracy: 0.5200
# Epoch 8/100
# 32/32 [==============================] - 2s 72ms/step - loss: 0.6309 - accuracy: 0.6938 - val_loss: 0.5723 - val_accuracy: 0.7000
# Epoch 9/100
# 32/32 [==============================] - 2s 70ms/step - loss: 0.6233 - accuracy: 0.6250 - val_loss: 0.5893 - val_accuracy: 0.7600
# Epoch 10/100
# 32/32 [==============================] - 2s 68ms/step - loss: 0.5585 - accuracy: 0.7312 - val_loss: 0.5733 - val_accuracy: 0.6200
# Epoch 11/100
# 32/32 [==============================] - 2s 68ms/step - loss: 0.5102 - accuracy: 0.8000 - val_loss: 0.6065 - val_accuracy: 0.6200
# Epoch 12/100
# 32/32 [==============================] - 2s 66ms/step - loss: 0.4946 - accuracy: 0.7937 - val_loss: 0.4001 - val_accuracy: 0.8200
# Epoch 13/100
# 32/32 [==============================] - 2s 67ms/step - loss: 0.4299 - accuracy: 0.8687 - val_loss: 0.3450 - val_accuracy: 0.8400
# Epoch 14/100
# 32/32 [==============================] - 2s 67ms/step - loss: 0.3470 - accuracy: 0.8750 - val_loss: 0.2327 - val_accuracy: 0.9400
# Epoch 15/100
# 32/32 [==============================] - 2s 66ms/step - loss: 0.2671 - accuracy: 0.9062 - val_loss: 0.1776 - val_accuracy: 0.9600
# Epoch 16/100
# 32/32 [==============================] - 2s 65ms/step - loss: 0.2855 - accuracy: 0.8562 - val_loss: 0.1541 - val_accuracy: 0.9600
# Epoch 17/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.2290 - accuracy: 0.9312 - val_loss: 0.2672 - val_accuracy: 0.8800
# Epoch 18/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1929 - accuracy: 0.9563 - val_loss: 0.1255 - val_accuracy: 0.9600
# Epoch 19/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1814 - accuracy: 0.9312 - val_loss: 0.0817 - val_accuracy: 0.9800
# Epoch 20/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1566 - accuracy: 0.9750 - val_loss: 0.0924 - val_accuracy: 0.9600
# Epoch 21/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1549 - accuracy: 0.9625 - val_loss: 0.1247 - val_accuracy: 0.9600
# Epoch 22/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1186 - accuracy: 0.9500 - val_loss: 0.0659 - val_accuracy: 0.9800
# Epoch 23/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.0905 - accuracy: 0.9750 - val_loss: 0.0372 - val_accuracy: 1.0000
# Epoch 24/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.0962 - accuracy: 0.9750 - val_loss: 0.2569 - val_accuracy: 0.8600
# Epoch 25/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1690 - accuracy: 0.9500 - val_loss: 0.0797 - val_accuracy: 0.9800
# Epoch 26/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.0738 - accuracy: 0.9750 - val_loss: 0.0831 - val_accuracy: 0.9600
# Epoch 27/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.0722 - accuracy: 0.9875 - val_loss: 0.1368 - val_accuracy: 0.9600
# Epoch 28/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.0959 - accuracy: 0.9750 - val_loss: 0.0638 - val_accuracy: 0.9600

# %%
# 검증셋과 학습셋의 오차를 저장합니다.
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

# 그래프로 표현해 봅니다.
x_len = np.arange(len(y_loss))
plt.plot(x_len, y_vloss, marker='.', c="red", label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')

# 그래프에 그리드를 주고 레이블을 표시하겠습니다.
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# # 전이 학습으로 모델 성능 극대화하기

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Input, models, layers, optimizers, metrics
from tensorflow.keras.layers import Dense, Flatten, Activation, Dropout
from tensorflow.keras.applications import VGG16
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import matplotlib.pyplot as plt

# 학습셋의 변형을 설정하는 부분입니다. 
train_datagen = ImageDataGenerator(rescale=1./255,          # 주어진 이미지의 크기를 설정합니다.
                                  horizontal_flip=True,     # 수평 대칭 이미지를 50% 확률로 만들어 추가합니다.
                                  width_shift_range=0.1,    # 전체 크기의 15% 범위에서 좌우로 이동합니다.
                                  height_shift_range=0.1,   # 마찬가지로 위, 아래로 이동합니다.
                                  #rotation_range=5,        # 정해진 각도만큼 회전시킵니다.
                                  #shear_range=0.7,         # 좌표 하나를 고정시키고 나머지를 이동시킵니다.
                                  #zoom_range=1.2,          # 확대 또는 축소시킵니다.
                                  #vertical_flip=True,      # 수직 대칭 이미지를 만듭니다.
                                  #fill_mode='nearest'      # 빈 공간을 채우는 방법입니다. nearest 옵션은 가장 비슷한 색으로 채우게 됩니다.
                                  )      


train_generator = train_datagen.flow_from_directory(
       './data/train',
       target_size=(150, 150),
       batch_size=5,
       class_mode='binary')

# 테스트셋의 정규화를 설정합니다.
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
       './data/test',
       target_size=(150, 150),
       batch_size=5,
       class_mode='binary')

# VGG16 모델을 불러옵니다.
transfer_model = VGG16(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
transfer_model.trainable = False
transfer_model.summary()

# 우리의 모델을 설정합니다.
finetune_model = models.Sequential()
finetune_model.add(transfer_model)
finetune_model.add(Flatten())
finetune_model.add(Dense(64))
finetune_model.add(Activation('relu'))
finetune_model.add(Dropout(0.5))
finetune_model.add(Dense(1))
finetune_model.add(Activation('sigmoid'))
finetune_model.summary()
# Out:
# Found 160 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 64)                524352
#
#  activation_5 (Activation)   (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
#  activation_6 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 15239105 (58.13 MB)
# Trainable params: 524417 (2.00 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
# 모델의 실행 옵션을 설정합니다. 
finetune_model.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(learning_rate=0.0002), metrics=['accuracy'])

# 학습의 조기 중단을 설정합니다.
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=5)

# 모델을 실행합니다.
history = finetune_model.fit(
       train_generator,
       epochs=20,
       validation_data=test_generator,
       validation_steps=10, 
       callbacks=[early_stopping_callback])
# Out:
# Epoch 1/20
# 32/32 [==============================] - 7s 197ms/step - loss: 0.6865 - accuracy: 0.6125 - val_loss: 0.5884 - val_accuracy: 0.6200
# Epoch 2/20
# 32/32 [==============================] - 6s 192ms/step - loss: 0.5129 - accuracy: 0.8000 - val_loss: 0.4335 - val_accuracy: 0.8400
# Epoch 3/20
# 32/32 [==============================] - 6s 194ms/step - loss: 0.4311 - accuracy: 0.7750 - val_loss: 0.4489 - val_accuracy: 0.8000
# Epoch 4/20
# 32/32 [==============================] - 6s 196ms/step - loss: 0.3547 - accuracy: 0.8438 - val_loss: 0.3021 - val_accuracy: 0.9000
# Epoch 5/20
# 32/32 [==============================] - 6s 195ms/step - loss: 0.2763 - accuracy: 0.9312 - val_loss: 0.2480 - val_accuracy: 0.9200
# Epoch 6/20
# 32/32 [==============================] - 6s 200ms/step - loss: 0.2811 - accuracy: 0.8938 - val_loss: 0.1856 - val_accuracy: 0.9600
# Epoch 7/20
# 32/32 [==============================] - 6s 187ms/step - loss: 0.2658 - accuracy: 0.9250 - val_loss: 0.1570 - val_accuracy: 1.0000
# Epoch 8/20
# 32/32 [==============================] - 6s 195ms/step - loss: 0.2396 - accuracy: 0.9187 - val_loss: 0.2101 - val_accuracy: 0.9600
# Epoch 9/20
# 32/32 [==============================] - 6s 203ms/step - loss: 0.2647 - accuracy: 0.9000 - val_loss: 0.1544 - val_accuracy: 1.0000
# Epoch 10/20
# 32/32 [==============================] - 7s 204ms/step - loss: 0.2218 - accuracy: 0.9375 - val_loss: 0.1653 - val_accuracy: 0.9600
# Epoch 11/20
# 32/32 [==============================] - 7s 208ms/step - loss: 0.1884 - accuracy: 0.9312 - val_loss: 0.1646 - val_accuracy: 0.9600
# Epoch 12/20
# 32/32 [==============================] - 7s 205ms/step - loss: 0.1866 - accuracy: 0.9438 - val_loss: 0.0921 - val_accuracy: 1.0000
# Epoch 13/20
# 32/32 [==============================] - 7s 207ms/step - loss: 0.1628 - accuracy: 0.9500 - val_loss: 0.1039 - val_accuracy: 0.9800
# Epoch 14/20
# 32/32 [==============================] - 6s 204ms/step - loss: 0.1529 - accuracy: 0.9438 - val_loss: 0.1230 - val_accuracy: 0.9800
# Epoch 15/20
# 32/32 [==============================] - 6s 203ms/step - loss: 0.1613 - accuracy: 0.9438 - val_loss: 0.1313 - val_accuracy: 0.9600
# Epoch 16/20
# 32/32 [==============================] - 7s 205ms/step - loss: 0.1542 - accuracy: 0.9625 - val_loss: 0.1942 - val_accuracy: 0.9400
# Epoch 17/20
# 32/32 [==============================] - 7s 212ms/step - loss: 0.1520 - accuracy: 0.9563 - val_loss: 0.1357 - val_accuracy: 0.9600

# %%
# 검증셋과 학습셋의 오차를 저장합니다.
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

# 그래프로 표현해 봅니다.
x_len = np.arange(len(y_loss))
plt.plot(x_len, y_vloss, marker='.', c="red", label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')

# 그래프에 그리드를 주고 레이블을 표시하겠습니다.
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
